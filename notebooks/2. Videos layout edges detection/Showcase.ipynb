# %%
from shutil import copyfile
import matplotlib.pyplot as plt
import torch

# %%
# %run './Layout extractor model.ipynb'

# %%
lm = LayoutModel('./LayoutTypeModelTree.pickle')

# %% [markdown]
# # Example of frame

# %%
frame = torch.load('./frame_2.pt').permute(0,3,1,2)
frame.shape
# Out:
# torch.Size([1, 3, 720, 1440])

# %% [markdown]
# # Visualize

# %%
plt.imshow(frame.permute(0,2,3,1).squeeze())

# %% [markdown]
# # Divide

# %%
d, positions = lm(frame)
positions = positions.squeeze()

# %%
d, positions
# Out:
# (tensor([1.]), tensor([0.3333, 0.3745, 0.4930]))

# %%
w = frame.shape[3]
h = frame.shape[2]

plt.imshow(frame.permute(0,2,3,1).squeeze())
plt.plot([a[0]*w, a[0]*w], [0, h-1], color='yellow')
plt.plot([0, a[0]*w], [a[2]*h, a[2]*h], color='yellow')

# %% [markdown]
# # Example of frame

# %%
frame = torch.load('./frame_1.pt').permute(0,3,1,2)

# %% [markdown]
# # Visualize

# %%
plt.imshow(frame.permute(0,2,3,1).squeeze())

# %% [markdown]
# # Divide

# %%
d, positions = lm(frame)
positions = positions.squeeze()

# %%
d, positions
# Out:
# (tensor([2.]), tensor([0.3412, 0.4974, 0.5112]))

# %%
w = frame.shape[3]
h = frame.shape[2]

plt.imshow(frame.permute(0,2,3,1).squeeze())
plt.plot([positions[1]*w, positions[1]*w], [0, h-1], color='yellow')
